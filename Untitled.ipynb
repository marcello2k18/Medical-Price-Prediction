# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
medical = pd.read_csv("medical_insurance.csv")
medical
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 2767   47  female  45.320         1     no  southeast   8569.86180
# 2768   21  female  34.600         0     no  southwest   2020.17700
# 2769   19    male  26.030         1    yes  northwest  16450.89470
# 2770   23    male  18.715         0     no  northwest  21595.38229
# 2771   54    male  31.600         0     no  southwest   9850.43200
#
# [2772 rows x 7 columns]

# %%
medical.info
# Out:
# <bound method DataFrame.info of       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 2767   47  female  45.320         1     no  southeast   8569.86180
# 2768   21  female  34.600         0     no  southwest   2020.17700
# 2769   19    male  26.030         1    yes  northwest  16450.89470
# 2770   23    male  18.715         0     no  northwest  21595.38229
# 2771   54    male  31.600         0     no  southwest   9850.43200
#
# [2772 rows x 7 columns]>

# %%
medical.describe()
# Out:
#                age          bmi     children       charges
# count  2772.000000  2772.000000  2772.000000   2772.000000
# mean     39.109668    30.701349     1.101732  13261.369959
# std      14.081459     6.129449     1.214806  12151.768945
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      26.000000    26.220000     0.000000   4687.797000
# 50%      39.000000    30.447500     1.000000   9333.014350
# 75%      51.000000    34.770000     2.000000  16577.779500
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# ### Preprocessing Data¶

# %%
medical.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#get_dummies to strings, sex, smoker and region and concat with original df
medical_dummied = pd.concat([medical, pd.get_dummies(medical[['sex', 'smoker', 'region']])], axis=1)

# %%
#drop the columns that i get_dummied
medical_dummied.drop(columns=['sex', 'smoker', 'region'], inplace=True)

# %%
medical_dummied.head()
# Out:
#    age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0   19  27.900         0  16884.92400        True     False      False
# 1   18  33.770         1   1725.55230       False      True       True
# 2   28  33.000         3   4449.46200       False      True       True
# 3   33  22.705         0  21984.47061       False      True       True
# 4   32  28.880         0   3866.85520       False      True       True
#
#    smoker_yes  region_northeast  region_northwest  region_southeast  \
# 0        True             False             False             False
# 1       False             False             False              True
# 2       False             False             False              True
# 3       False             False              True             False
# 4       False             False              True             False
#
#    region_southwest
# 0              True
# 1             False
# 2             False
# 3             False
# 4             False

# %% [markdown]
# ### EDA (Exploratory Data Analysis)¶

# %%
medical.describe() .T
# Out:
#            count          mean           std        min       25%         50%  \
# age       2772.0     39.109668     14.081459    18.0000    26.000    39.00000
# bmi       2772.0     30.701349      6.129449    15.9600    26.220    30.44750
# children  2772.0      1.101732      1.214806     0.0000     0.000     1.00000
# charges   2772.0  13261.369959  12151.768945  1121.8739  4687.797  9333.01435
#
#                  75%          max
# age          51.0000     64.00000
# bmi          34.7700     53.13000
# children      2.0000      5.00000
# charges   16577.7795  63770.42801

# %% [markdown]
# ###### The dataset contains 2,772 entries across 7 columns, focusing on individual medical costs billed by health insurance. The key variable of interest, "charges," is a continuous float value, reflecting the insurance cost associated with each individual. The dataset spans a broad age range, notably featuring a significant number of individuals between 18 to 22.5 years, predominantly male. Most have fewer than three children, and the bulk falls within a BMI range indicating overweight to moderate obesity (29.26 to 31.16). The data encompasses four regions (northeast, northwest, southeast, and southwest), with a higher prevalence of smokers in the southeast. This analysis aims to explore how age, sex, BMI, children, smoking status, and region influence insurance costs, with a keen interest in statistical correlations and patterns that may emerge.

# %% [markdown]
# ### Distribution of Demographic and Behavioral Characteristics

# %%
fig, axs = plt.subplots(5, figsize=(8,10))

axs[0].hist(medical['age'], bins=20)
axs[0].set_title('Age Distribution')
axs[0].set_xlabel('Age')
axs[0].set_ylabel('Count')

axs[1].hist(medical['children'], bins=20)
axs[1].set_title('Children Distribution')
axs[1].set_xlabel('Children')
axs[1].set_ylabel('Count')

axs[2].hist(medical['smoker'], bins=20)
axs[2].set_title('Smoker Distribution')
axs[2].set_xlabel('Smoker')
axs[2].set_ylabel('Count')

axs[3].hist(medical['sex'], bins=20)
axs[3].set_title('Sex Distribution')
axs[3].set_xlabel('Sex')
axs[3].set_ylabel('Count')

axs[4].hist(medical['region'], bins=20)
axs[4].set_title('Region Distribution')
axs[4].set_xlabel('Region')
axs[4].set_ylabel('Count')

plt.tight_layout()

plt.show()

# %% [markdown]
# These plots collectively offer insights into the demographics and behaviors of the individuals in the dataset, highlighting the prevalence of younger individuals, the tendency towards smaller family sizes, the lower smoking rates, a balanced gender distribution, and an even regional spread. Such visualizations are critical for understanding the dataset's composition and guiding further analysis on how these factors might influence insurance charges.

# %% [markdown]
# ### What are the primary factors influencing medical expenses?¶

# %%
plt.figure(figsize=(12,9))
sns.heatmap(medical_dummied.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %% [markdown]
# The observations from the analysis reveal several key insights into the factors influencing insurance charges. The most striking correlation is found between smoking status and charges, indicating a substantial increase in insurance costs for smokers due to their higher health risks. This aligns with established knowledge regarding the detrimental health effects of smoking. Additionally, age and BMI also exhibit positive correlations with charges, reflecting the expected higher medical expenses associated with older age and increased BMI levels. While regional differences show some correlation with charges, their impact appears to be less significant compared to smoking, age, and BMI. Surprisingly, gender and the number of children show minimal correlation with charges, suggesting these factors have little influence on insurance costs in this dataset. Overall, these findings emphasize the critical role of lifestyle choices and demographic characteristics in determining health insurance premiums, providing valuable insights for risk management and pricing strategies in the insurance industry.

# %% [markdown]
# ### Scatter to smoker - charges

# %%
plt.scatter(medical['smoker'], medical['charges'], s=5)
plt.title("Smoker - Charges")
plt.xlabel('Smoker')
plt.ylabel('Charges')
plt.show()

# %% [markdown]
# The observations drawn from the scatter plot analysis reveal distinct patterns within the data. Notably, there are two evident clusters, delineating smokers and non-smokers. This stark division underscores the profound impact of smoking status on insurance charges, with smokers consistently displaying higher costs compared to non-smokers. Moreover, within each cluster, there exists notable variation, particularly among smokers, suggesting that factors beyond smoking, such as age, BMI, and comorbidities, also significantly influence individual insurance charges. Overall, the scatter plot confirms the hypothesis that smoking status is a crucial predictor of elevated medical expenses, emphasizing the necessity for insurers to incorporate smoking status into risk assessments and premium calculations. Additionally, it suggests that a holistic approach to risk assessment, encompassing various factors beyond smoking alone, would enhance the accuracy of insurance pricing models.

# %% [markdown]
# ### Charges mean between smokers and non smokers

# %%
smoker_charges = medical[medical["smoker"] == "yes"]["charges"]
non_smoker_charges = medical[medical["smoker"] == "no"]["charges"]

mean_smoker_charges = smoker_charges.mean()
mean_non_smoker_charges = non_smoker_charges.mean()

print(f"Mean charges for smokers: {mean_smoker_charges}")
print(f"Mean charges for non-smokers: {mean_non_smoker_charges}")
# Out:
# Mean charges for smokers: 32223.139763617022
# Mean charges for non-smokers: 8417.8744111404

# %% [markdown]
# The analysis reveals a significant discrepancy in insurance charges between smokers and non-smokers. On average, smokers face much higher costs, around $32,223.14, compared to approximately $8,417.87 for non-smokers. This stark contrast emphasizes the substantial financial risk associated with smoking, underscoring its critical role in insurance pricing and risk assessment.
#
# The principal factor to medical expenses are smokers, with 79% correlation, followed by age with 30% correlation and bmi with 20%.

# %% [markdown]
# ### More Statistics¶

# %%
#subplots bar
fig, axs = plt.subplots(3, figsize=(12,10))

axs[0].bar(medical['age'], medical['charges'])
axs[0].set_title('Age - Charges')
axs[0].set_xlabel('Age')
axs[0].set_ylabel('Charge')

axs[1].bar(medical['age'], medical['bmi'])
axs[1].set_title('Age - BMI')
axs[1].set_xlabel('Age')
axs[1].set_ylabel('BMI')

axs[2].bar(medical['age'], medical['children'])
axs[2].set_title('Age - Children')
axs[2].set_xlabel('Age')
axs[2].set_ylabel('Children')

plt.tight_layout()

plt.show()

# %%
#subplots bar
fig, axs = plt.subplots(2, figsize=(6,6))

axs[0].bar(medical['sex'], medical['bmi'])
axs[0].set_title('Sex - BMI')
axs[0].set_xlabel('Sex')
axs[0].set_ylabel('BMI')

axs[1].bar(medical['smoker'], medical['bmi'])
axs[1].set_title('Smoker - BMI')
axs[1].set_xlabel('Smoker')
axs[1].set_ylabel('BMI')

plt.tight_layout()

plt.show()

# %%
#female and male smokers
medical.groupby(['smoker', 'sex']).size().unstack()
# Out:
# sex     female  male
# smoker
# no        1134  1074
# yes        232   332

# %%
#subploits boxplots
fig, axs = plt.subplots(4, figsize=(5, 8))

axs[0].boxplot(medical['age'], vert=False)
axs[0].set_title('Age - BOXPLOT')

axs[1].boxplot(medical['bmi'], vert=False)
axs[1].set_title('BMI - BOXPLOT')

axs[2].boxplot(medical['children'], vert=False)
axs[2].set_title('Children - BOXPLOT')

axs[3].boxplot(medical['charges'], vert=False)
axs[3].set_title('Charges - BOXPLOT')

plt.tight_layout()
plt.show()

# %% [markdown]
# The smokers make this Charges outliers, this will affect our model later

# %% [markdown]
# ## Training and Testing Models¶

# %% [markdown]
# ### To what extent do Machine Learning Models accurately predict medical expenses?

# %% [markdown]
# #### Import necessary models and libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression, Ridge, LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, r2_score, mean_squared_error, mean_absolute_error, roc_curve, auc
from xgboost import XGBClassifier

# %%
categorical_features = ['sex', 'smoker', 'region']
one_hot = OneHotEncoder()
transformer = ColumnTransformer([("one_hot", one_hot, categorical_features)], remainder="passthrough")
X_transformed = transformer.fit_transform(medical.drop('charges', axis=1))
y = medical['charges']

# %% [markdown]
# The dataset is transformed for machine learning by encoding categorical features using one-hot encoding, while numerical features remain unchanged. This prepares the data for model training, with the charges column as the target variable.

# %% [markdown]
# #### Split the dataset into training and testing sets for regression

# %%
X_train, X_test, y_train, y_test = train_test_split(X_transformed, y, test_size=0.2, random_state=42)

# %% [markdown]
# #### Models for regression

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
models = {
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(),
    "Lasso Regression": Lasso(),
    "Elastic Net Regression": ElasticNet(),
    "Decision Tree Regression": DecisionTreeRegressor(),
    "Random Forest Regression": RandomForestRegressor(),
    "Gradient Boosting Regression": GradientBoostingRegressor(),
    "Support Vector Regression": SVR(),
    "K-Nearest Neighbors Regression": KNeighborsRegressor(),
    "XGBoost Regression": XGBRegressor(),
    "LightGBM Regression": LGBMRegressor(),
    "CatBoost Regression": CatBoostRegressor(),
    "Extra Trees Regression": ExtraTreesRegressor()
}

# %%
print("Regression Models Evaluation:")
for name, model in models.items():
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    r2_score_model = r2_score(y_test, predictions)
    mse_score = mean_squared_error(y_test, predictions)
    mae_score = mean_absolute_error(y_test, predictions)

    print("Model:", name)
    print("R2 Score:", r2_score_model)
    print("MSE Score:", mse_score)
    print("MAE Score:", mae_score)
    print()
# Out:
# Regression Models Evaluation:
# Model: Linear Regression
# R2 Score: 0.73981661775643
# MSE Score: 39933194.54805148
# MAE Score: 4160.247974762991
#
# Model: Ridge Regression
# R2 Score: 0.7397837206133643
# MSE Score: 39938243.633057564
# MAE Score: 4162.651223855457
#
# Model: Lasso Regression
# R2 Score: 0.7398079787797978
# MSE Score: 39934520.466454
# MAE Score: 4160.520766055936
#
# Model: Elastic Net Regression
# R2 Score: 0.5234710858266627
# MSE Score: 73138113.86939906
# MAE Score: 6232.074910367434
#
# Model: Decision Tree Regression
# R2 Score: 0.9547986818136645
# MSE Score: 6937541.580859071
# MAE Score: 520.2267985765766
#
# Model: Random Forest Regression
# R2 Score: 0.9501392702183221
# MSE Score: 7652672.5323894955
# MAE Score: 1307.10300021209
#
# Model: Gradient Boosting Regression
# R2 Score: 0.8745359418641633
# MSE Score: 19256343.733882822
# MAE Score: 2304.7186285469547
#
# Model: Support Vector Regression
# R2 Score: -0.07104023881587151
# MSE Score: 164384281.0275509
# MAE Score: 8296.720292302423
#
# Model: K-Nearest Neighbors Regression
# R2 Score: 0.5169989214374635
# MSE Score: 74131467.85485423
# MAE Score: 4856.035749977657
#
# Model: XGBoost Regression
# R2 Score: 0.9585236639034349
# MSE Score: 6365827.764257357
# MAE Score: 1115.8786295930108
#
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000816 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 324
# [LightGBM] [Info] Number of data points in the train set: 2217, number of used features: 11
# [LightGBM] [Info] Start training from score 13371.074037
# Model: LightGBM Regression
# R2 Score: 0.9040252550013865
# MSE Score: 14730295.727116814
# MAE Score: 2142.5153173035314
#
# Learning rate set to 0.046431
# 0:	learn: 11650.2231941	total: 60.5ms	remaining: 1m
# 1:	learn: 11218.1721645	total: 61ms	remaining: 30.4s
# 2:	learn: 10822.9869750	total: 61.7ms	remaining: 20.5s
# 3:	learn: 10429.1581216	total: 62.5ms	remaining: 15.6s
# 4:	learn: 10082.4381221	total: 63.2ms	remaining: 12.6s
# 992:	learn: 2337.3599286	total: 684ms	remaining: 4.82ms
# 993:	learn: 2335.9663617	total: 684ms	remaining: 4.13ms
# 994:	learn: 2335.0585931	total: 685ms	remaining: 3.44ms
# 995:	learn: 2333.1993871	total: 685ms	remaining: 2.75ms
# 996:	learn: 2332.5109393	total: 686ms	remaining: 2.06ms
# 997:	learn: 2331.3388006	total: 686ms	remaining: 1.38ms
# 998:	learn: 2330.0329905	total: 687ms	remaining: 688us
# 999:	learn: 2328.6525339	total: 688ms	remaining: 0us
# Model: CatBoost Regression
# R2 Score: 0.9222429654383886
# MSE Score: 11934224.09168919
# MAE Score: 1820.5364724116096
#
# Model: Extra Trees Regression
# R2 Score: 0.9632311031591189
# MSE Score: 5643325.481446759
# MAE Score: 553.6773566483015

# %% [markdown]
# Based on the provided evaluation metrics, the "Extra Trees Regression" model emerges as the top performer among the listed models. It achieved the highest R2 score of approximately 0.962, indicating superior ability to explain the variance in the target variable. Additionally, this model demonstrated the lowest MSE and MAE scores, reflecting smaller errors in prediction compared to other models. Taken together, these metrics suggest that the "Extra Trees Regression" model excels in predicting hospital fee charges, making it the preferred choice for this task.

# %% [markdown]
# ##### Preparing for classification

# %%
medical['charges_category'] = (medical['charges'] > medical['charges'].median()).astype(int)
y_categorical = medical['charges_category']
X_train_cat, X_test_cat, y_train_cat, y_test_cat = train_test_split(X_transformed, y_categorical, test_size=0.2, random_state=42)

# %% [markdown]
# The continuous variable charges is transformed into a binary categorical variable, charges_category, based on whether each value is above or below the median charge. This allows for a shift from regression to classification tasks, dividing the dataset into two balanced groups: above and below the median charges. With equal instances in each category, the dataset is split for training and testing classification models effectively, providing a simplified approach for insurance risk categorization based on a median threshold.

# %% [markdown]
# #### Models for classification

# %%
classifications_models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "KNN Classification": KNeighborsClassifier(),
    "SVM Classification": SVC(probability=True),
    "Naive Bayes Classification": GaussianNB(),
    "XGBoost Classification": XGBClassifier()
}

# %% [markdown]
# #### Train and evaluate classification models

# %%
print("\nClassification Models Evaluation:")
for name, model in classifications_models.items():
    model.fit(X_train_cat, y_train_cat)
    if name == "SVM Classification":
        predictions = model.decision_function(X_test_cat)
    else:
        predictions = model.predict_proba(X_test_cat)[:, 1]
    accuracy = accuracy_score(y_test_cat, model.predict(X_test_cat))
    print(f"{name}: Accuracy = {accuracy:.2f}")
# Out:
# Classification Models Evaluation:
# Logistic Regression: Accuracy = 0.92
# KNN Classification: Accuracy = 0.87
# SVM Classification: Accuracy = 0.81
# Naive Bayes Classification: Accuracy = 0.69
# XGBoost Classification: Accuracy = 0.97

# %% [markdown]
# In the evaluation of classification models based on the provided data, Logistic Regression exhibited the highest accuracy of 92%. It was closely followed by KNN Classification with an accuracy of 87%, and SVM Classification with an accuracy of 81%. Naive Bayes Classification lagged behind with an accuracy of 69%. Notably, XGBoost Classification outperformed all other models with an accuracy of 97%, making it the most accurate model for categorizing individuals into two groups based on insurance charges.

# %% [markdown]
# #### ROC Curve Analysis

# %%
plt.figure(figsize=(10, 8))
for name, model in classifications_models.items():
    if name == "SVM Classification":
        predictions = model.decision_function(X_test_cat)
    else:
        predictions = model.predict_proba(X_test_cat)[:, 1]
    fpr, tpr, _ = roc_curve(y_test_cat, predictions)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{name} (area = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve Comparison')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# Enough said for me, Logistic Regression and KNN show really high AUC scores, this indicate strong perfomance. SVM performs little bit worse, while Naive Bayes Classification is little bit weaker while SVM is the weakest right here.

# %% [markdown]
# ### New Instance Testing¶

# %%
from sklearn.linear_model import LinearRegression

# Instantiate the LinearRegression model
linear_reg_model = LinearRegression()

# Fit the model to the training data
linear_reg_model.fit(X_train, y_train)

# User Input Function
def get_user_input():
    age = int(input("Enter age: "))
    sex = input("Enter sex (male/female): ")
    bmi = float(input("Enter BMI: "))
    children = int(input("Enter number of children: "))
    smoker = input("Enter smoker (yes/no): ")
    region = input("Enter region (southwest/southeast/northwest/northeast): ")

    return age, sex, bmi, children, smoker, region

# Get user input
age, sex, bmi, children, smoker, region = get_user_input()

# Create a sample input (like a DataFrame)
user_data = pd.DataFrame([[age, sex, bmi, children, smoker, region]], columns=['age', 'sex', 'bmi', 'children', 'smoker', 'region'])

# Apply the same transformations
user_data_transformed = transformer.transform(user_data)

# Regression Predictions
print("\nRegression Predictions:")
for name, model in models.items():
    prediction = model.predict(user_data_transformed)[0]  # Get the single prediction
    print(f"{name}: Predicted charges: ${prediction:.2f}")

# Classification Predictions
print("\nClassification Predictions:")
for name, model in classifications_models.items():
    prediction = model.predict(user_data_transformed)[0]
    if prediction == 1:
        pred_class = "High charges"
    else:
        pred_class = "Low charges"
    print(f"{name}: Predicted category: {pred_class}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [28], in <cell line: 21>()
#      18     return age, sex, bmi, children, smoker, region
#      20 # Get user input
# ---> 21 age, sex, bmi, children, smoker, region = get_user_input()
#      23 # Create a sample input (like a DataFrame)
#      24 user_data = pd.DataFrame([[age, sex, bmi, children, smoker, region]], columns=['age', 'sex', 'bmi', 'children', 'smoker', 'region'])
#
# Input In [28], in get_user_input()
#      10 def get_user_input():
# ---> 11     age = int(input("Enter age: "))
#      12     sex = input("Enter sex (male/female): ")
#      13     bmi = float(input("Enter BMI: "))
#
# File ~/anaconda3/envs/data/lib/python3.9/site-packages/ipykernel/kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# File ~/anaconda3/envs/data/lib/python3.9/site-packages/ipykernel/kernelbase.py:1245, in Kernel._input_request(self, prompt, ident, parent, password)
#    1242 except KeyboardInterrupt:
#    1243     # re-raise KeyboardInterrupt, to truncate traceback
#    1244     msg = "Interrupted by user"
# -> 1245     raise KeyboardInterrupt(msg) from None
#    1246 except Exception:
#    1247     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier

# Define your classification models dictionary
classifications_models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "KNN Classification": KNeighborsClassifier(),
    "SVM Classification": SVC(probability=True),
    "Naive Bayes Classification": GaussianNB(),
    "XGBoost Classification": XGBClassifier(),
    "Random Forest Classification": RandomForestClassifier(),
    "AdaBoost Classification": AdaBoostClassifier(),
    "MLP Classifier": MLPClassifier(max_iter=1000),
    "Decision Tree Classification": DecisionTreeClassifier()
}

# Fit and evaluate each model
for name, model in classifications_models.items():
    # Fit the model if necessary
    model.fit(X_train_cat, y_train_cat)  # Ensure model is fitted
    
    # Predict using the model
    y_pred = model.predict(X_test_cat)
    
    # Generate confusion matrix
    cm = confusion_matrix(y_test_cat, y_pred)
    
    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, cmap='Blues', fmt='g')
    plt.title(f'Confusion Matrix for {name}')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()
    
    # Print confusion matrix with model name
    print(f"Confusion Matrix for {name}:")
    print(cm)
    print("\n")
# Out:
# Confusion Matrix for Logistic Regression:
# [[268  16]
#  [ 31 240]]
# Confusion Matrix for KNN Classification:
# [[272  12]
#  [ 62 209]]
# Confusion Matrix for SVM Classification:
# [[264  20]
#  [ 85 186]]
# Confusion Matrix for Naive Bayes Classification:
# [[284   0]
#  [171 100]]
# Confusion Matrix for XGBoost Classification:
# [[284   0]
#  [ 14 257]]
# Confusion Matrix for Random Forest Classification:
# [[282   2]
#  [  9 262]]
# /Users/roy/anaconda3/envs/data/lib/python3.9/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Confusion Matrix for AdaBoost Classification:
# [[281   3]
#  [ 36 235]]
# Confusion Matrix for MLP Classifier:
# [[271  13]
#  [ 37 234]]
# Confusion Matrix for Decision Tree Classification:
# [[280   4]
#  [  9 262]]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# Function to train classification models and evaluate them
def train_classification_models(self):
    self.data['charges_category'] = (self.data['charges'] > self.data['charges'].median()).astype(int)
    y_categorical = self.data['charges_category']
    X_train_cat, X_test_cat, y_train_cat, y_test_cat = train_test_split(
        self.X_transformed, y_categorical, test_size=0.2, random_state=42)

    models = {
        "Logistic Regression": LogisticRegression(max_iter=1000),
        "KNN Classification": KNeighborsClassifier(),
        "SVM Classification": SVC(probability=True),
        "Naive Bayes Classification": GaussianNB(),
        "XGBoost Classification": XGBClassifier()
    }
    
    for name, model in models.items():
        model.fit(X_train_cat, y_train_cat)
        self.classification_models[name] = model

        # Evaluate the model
        y_pred = model.predict(X_test_cat)
        cm = confusion_matrix(y_test_cat, y_pred)
        accuracy = accuracy_score(y_test_cat, y_pred)
        precision = precision_score(y_test_cat, y_pred)
        recall = recall_score(y_test_cat, y_pred)
        f1 = f1_score(y_test_cat, y_pred)

        # Print confusion matrix and metrics
        print(f"Evaluation metrics for {name}:")
        print("Confusion Matrix:")
        print(cm)
        print(f"Accuracy: {accuracy:.2f}")
        print(f"Precision: {precision:.2f}")
        print(f"Recall: {recall:.2f}")
        print(f"F1 Score: {f1:.2f}")
        print("\n")

# %%
model = MedicalInsuranceModel('untitled.csv')

# Preprocess and split the data
model._preprocess_data()

# Train and evaluate classification models
model.train_classification_models()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 model = MedicalInsuranceModel('untitled.csv')
#       3 # Preprocess and split the data
#       4 model._preprocess_data()
#
# NameError: name 'MedicalInsuranceModel' is not defined
